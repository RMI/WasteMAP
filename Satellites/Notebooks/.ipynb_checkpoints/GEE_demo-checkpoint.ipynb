# %%
import ee
import geemap.foliumap as geemap
import pandas as pd
import glob
import math

# %%
ee.Authenticate()
ee.Initialize()
print(ee.Image("NASA/NASADEM_HGT/001").get("title").getInfo())
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=f2UL9haFQuLKU_hL87I0RExa1TkniUZNEdSeZt-cOc8&tc=bkXacAqVwrlR2T6_p7MnxtqHutUHbFrxf2z94URUC1w&cc=FMEu3gir0vFjF7b4q4-l2w_QZ0aK7eUIbp7w79bwJYE>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=f2UL9haFQuLKU_hL87I0RExa1TkniUZNEdSeZt-cOc8&tc=bkXacAqVwrlR2T6_p7MnxtqHutUHbFrxf2z94URUC1w&cc=FMEu3gir0vFjF7b4q4-l2w_QZ0aK7eUIbp7w79bwJYE</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AbUR2VMqPx6hdCf7IafdHhClyooo0OcgN0TnnbxrupdNDV-KcpzxwhnYb1M
#
# Successfully saved authorization token.
# NASADEM: NASA NASADEM Digital Elevation 30m

# %%
def load_NAIP(point, lat, lon):
    # NAIP Satellite and desired bands
    dataset='USDA/NAIP/DOQQ'
    bands = ['R', 'G', 'B']
    
    # Get the images that meet location and time criteria
    image_collection = ee.ImageCollection(dataset)\
            .filterBounds(point)\
            .sort('system:time_start', False)
    
    # Create a composite so we can make a square image of desired size around point
    composite = create_composite(image_collection)
    
    return composite, bands
    
def load_SkySat(point, lat, lon):
    dataset="SKYSAT/GEN-A/PUBLIC/ORTHO/RGB"
    bands = ['R', 'G', 'B']
    image_collection = ee.ImageCollection(dataset)\
            .filterBounds(point)\
            .sort('system:time_start', False)
    composite = create_composite(image_collection)
    return composite, bands

def load_Sentinal2(point, lat, lon):
    dataset="COPERNICUS/S2_SR_HARMONIZED"
    
    # Sentinal-2 has a lot of bands to choose from, see GEE catalogue
    bands = ['TCI_R', 'TCI_G', 'TCI_B']
    image_collection = ee.ImageCollection(dataset)\
            .filterBounds(point)\
            .sort('system:time_start', False)
    composite = create_composite(image_collection)
    return composite, bands

def create_composite(image_collection):
    # Define a rectangle around the point (6km x 6km)
    region = point.buffer(3000).bounds()
    
    # Create a composite
    composite = image_collection.median()
    
    # Clip the composite to the desired region
    composite = composite.clip(region)
    
    return composite

# This function works sometimes, but with GEE servers it seems to be unstable.
# def get_image(lat, lon):
#     sats_to_try = [load_NAIP, load_SkySat, load_Sentinal2]
#     sat_names = ['NAIP', 'SkySat', 'Sentinal2']
#     point = ee.Geometry.Point(lon, lat)
    
#     for i, sat in enumerate(sats_to_try):
#         try:
#             img, bands = sat(point, lat, lon)
#             # Make sure there's actually an image for this satellite
#             assert img.getInfo()['properties']['system:footprint'], print(f"No images found at location ({lat}, {lon}) for {sat_names[i]}")
#             # Create an interactive map and add the image layer
#             #centroid = img.geometry().centroid(1).getInfo()['coordinates']
#             #Map.setCenter(lon=centroid[0], lat=centroid[1], zoom=12)
#             Map = geemap.Map(center=[lat, lon], zoom=12)
#             Map.addLayer(img, {'bands': bands, 'min': 0, 'max': 255}, (str(lat) + '_' + str(lon)))
#             Map.addLayer(point, {}, 'Point_' + str(lat) + '_' + str(lon))
#             display(Map)
#             return #Map, centroid
#         except:
#             pass
#             #print(f"Nog images found at location ({lat}, {lon}) for {sat_names[i]}")
#     return #Map , centroid

# %%
# Load desired lat lon points
matches_df = pd.read_csv('m.csv')
matches_df
# Out:
#     lat_TRACE  lon_TRACE  idx_TRACE  lat_SRON  lon_SRON  idx_SRON  distance
# 0   35.471645  51.335506          6     35.46     51.34        46  1.387938
# 1  -34.543823 -58.606911         17    -34.52    -58.61       157  2.671162
# 2   18.684505  73.824041        348     18.66     73.83       410  2.804252
# 3   21.107957  72.804579        374     21.12     72.82       229  2.175673
# 4   16.918785  96.183778        440     16.90     96.17       470  2.590411
# 5   29.424167 -95.190834        995     29.42    -95.20       506  1.119592
# 6   22.279169  73.168368       1028     22.28     73.19       587  2.407188
# 7   19.234371  72.827992       1386     19.25     72.83       403  1.752206
# 8   18.891292  72.935481       1445     18.91     72.95       555  2.633186
# 9   41.214423  28.149789       1818     41.23     28.16       313  2.071063
# 10  23.249416  72.499246       1880     23.26     72.49       582  1.562703
# 11  22.326541  73.149549       2378     22.34     73.15       593  1.497374
# 12  23.095610  72.617210       2743     23.08     72.62       225  1.763302
# 13  17.495651  78.580171       2921     17.49     78.56       572  2.329289
# 14  26.764321  80.908509       3451     26.77     80.91       548  0.652824
# 15  28.714937  77.082245       3517     28.73     77.10       583  2.589019

# %%
# Standard loop to plot images

# Choose desired satellites in priority order
# NAIP and SkySat are ~1m resolution, but only available in the US
sats_to_try = [load_NAIP, load_SkySat, load_Sentinal2]
sat_names = ['NAIP', 'SkySat', 'Sentinal2']

for i, row in matches_df.iterrows():
    lat = matches_df.at[i, 'lat_TRACE']
    lon = matches_df.at[i, 'lon_TRACE']
    
    # Create a GEE point
    point = ee.Geometry.Point(lon, lat)
    
    # Loop through satellite options in priority order. If an image is found, break. 
    # If image not found, try next satellite.
    for i, sat in enumerate(sats_to_try):
        try:
            img, bands = sat(point, lat, lon)
            
            # Make sure there's actually an image for this satellite
            assert img.getInfo()['properties']['system:footprint']
            
            # Make sure the right bands are available
            assert set(bands).issubset(set(img.bandNames().getInfo()))
            
            # Create an interactive map and add the image layer
            Map = geemap.Map(center=[lat, lon], zoom=13)
            
            # Map the image
            Map.addLayer(img, {'bands': bands, 'min': 0, 'max': 255}, (str(lat) + '_' + str(lon)))
            
            # Add the lat lon point
            Map.addLayer(point, {}, 'Point_' + str(lat) + '_' + str(lon))
            display(Map)
            
#             # Define export parameters. Uncomment this if you want to export to Google Drive.
#             # Be careful though. These files can be quite large and numerous. 
#             exportParams = {
#                 'image': img,
#                 'description': 'Satellite_Image_' + sat_names[i] + '_' + str(lat) + '_' + str(lon),
#                 'region': img.geometry(),
#                 'folder': 'GEE_test', # specify Google Drive folder name 
#                 'fileFormat': 'GeoTIFF' # specify format
#             }

#             # Export the image to Google Drive
#             task = ee.batch.Export.image.toDrive(**exportParams)
#             task.start()
            
            break
        except:
            print(f"No images found at location ({lat}, {lon}) for {sat_names[i]}")
            pass
# Out:
# No images found at location (35.4716451185922, 51.3355064392089) for NAIP
# No images found at location (35.4716451185922, 51.3355064392089) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d707339554f037c663682d0207544b8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d707339554f037c663682d0207544b8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d707339554f037c663682d0207544b8f = L.map(
#                 &quot;map_d707339554f037c663682d0207544b8f&quot;,
#                 {
#                     center: [35.4716451185922, 51.3355064392089],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06bdc05ae24325a7b399e20ec654c3dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d707339554f037c663682d0207544b8f);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d707339554f037c663682d0207544b8f);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_d707339554f037c663682d0207544b8f);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_d707339554f037c663682d0207544b8f
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_f43af1b5ca48d93f3d045157fb0eff5e = new L.Control.Draw(
#                 options
#             ).addTo( map_d707339554f037c663682d0207544b8f );
#             map_d707339554f037c663682d0207544b8f.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_d707339554f037c663682d0207544b8f.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_d707339554f037c663682d0207544b8f.setView(e.geocode.center, 11);
#             }).addTo(map_d707339554f037c663682d0207544b8f);
#
#
#
#             map_d707339554f037c663682d0207544b8f.fitBounds(
#                 [[35.4716451185922, 51.3355064392089], [35.4716451185922, 51.3355064392089]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_315b608196bbeb5f1c12a8a2a8678180 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/3678e11a1ef43e2af016dbdbc2b7d3a7-3059637a4ff22d89bfd6144b97e46a9f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot
# No images found at location (-34.5438228657023, -58.6069107055664) for NAIP
# No images found at location (-34.5438228657023, -58.6069107055664) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88e8de745aae61c22fc1b2e289418ce2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88e8de745aae61c22fc1b2e289418ce2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88e8de745aae61c22fc1b2e289418ce2 = L.map(
#                 &quot;map_88e8de745aae61c22fc1b2e289418ce2&quot;,
#                 {
#                     center: [-34.5438228657023, -58.6069107055664],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cd3bb4ca9b93f3da00468ebc6840594 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88e8de745aae61c22fc1b2e289418ce2);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88e8de745aae61c22fc1b2e289418ce2);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_88e8de745aae61c22fc1b2e289418ce2);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_88e8de745aae61c22fc1b2e289418ce2
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_4afe21484dbdeb53650ec1ffc293bab6 = new L.Control.Draw(
#                 options
#             ).addTo( map_88e8de745aae61c22fc1b2e289418ce2 );
#             map_88e8de745aae61c22fc1b2e289418ce2.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_88e8de745aae61c22fc1b2e289418ce2.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_88e8de745aae61c22fc1b2e289418ce2.setView(e.geocode.center, 11);
#             }).addTo(map_88e8de745aae61c22fc1b2e289418ce2);
#
#
#
#             map_88e8de745aae61c22fc1b2e289418ce2.fitBounds(
#                 [[-34.5438228657023, -58.6069107055664], [-34.5438228657023, -58.6069107055664]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_0a9b70622d13e4571b58ffe5a1592e00 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/a062654c2723e00ed63c5a6bb20690be-977e10da8bd74fa3fdbc9c517ad99e06/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoo
# No images found at location (18.68450504818949, 73.82404071330201) for NAIP
# No images found at location (18.68450504818949, 73.82404071330201) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93290cca5eb0a337db6b8fcda755085b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93290cca5eb0a337db6b8fcda755085b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93290cca5eb0a337db6b8fcda755085b = L.map(
#                 &quot;map_93290cca5eb0a337db6b8fcda755085b&quot;,
#                 {
#                     center: [18.68450504818949, 73.82404071330201],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a18ccd9a04e6d9c368137bbb077966a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93290cca5eb0a337db6b8fcda755085b);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_93290cca5eb0a337db6b8fcda755085b);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_93290cca5eb0a337db6b8fcda755085b);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_93290cca5eb0a337db6b8fcda755085b
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_7d15f5ec374c6996a9c0cc443908afaf = new L.Control.Draw(
#                 options
#             ).addTo( map_93290cca5eb0a337db6b8fcda755085b );
#             map_93290cca5eb0a337db6b8fcda755085b.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_93290cca5eb0a337db6b8fcda755085b.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_93290cca5eb0a337db6b8fcda755085b.setView(e.geocode.center, 11);
#             }).addTo(map_93290cca5eb0a337db6b8fcda755085b);
#
#
#
#             map_93290cca5eb0a337db6b8fcda755085b.fitBounds(
#                 [[18.68450504818949, 73.82404071330201], [18.68450504818949, 73.82404071330201]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_14ac20f17d8bc1369aa22dcfa968a64a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/85fd449d0da35631cd301938c461a8f0-e0b6cb0cfa87e17e2c256fdb3affb40f/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoo
# No images found at location (21.10795732558601, 72.80457877828213) for NAIP
# No images found at location (21.10795732558601, 72.80457877828213) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14db751bafb5304eba86a522b6066193 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14db751bafb5304eba86a522b6066193&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14db751bafb5304eba86a522b6066193 = L.map(
#                 &quot;map_14db751bafb5304eba86a522b6066193&quot;,
#                 {
#                     center: [21.10795732558601, 72.80457877828213],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_accf2cc9f710b2b2b7c8aa467343d76b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14db751bafb5304eba86a522b6066193);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14db751bafb5304eba86a522b6066193);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_14db751bafb5304eba86a522b6066193);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_14db751bafb5304eba86a522b6066193
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_19f8c8e8e5704acd681bf03fecffc20c = new L.Control.Draw(
#                 options
#             ).addTo( map_14db751bafb5304eba86a522b6066193 );
#             map_14db751bafb5304eba86a522b6066193.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_14db751bafb5304eba86a522b6066193.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_14db751bafb5304eba86a522b6066193.setView(e.geocode.center, 11);
#             }).addTo(map_14db751bafb5304eba86a522b6066193);
#
#
#
#             map_14db751bafb5304eba86a522b6066193.fitBounds(
#                 [[21.10795732558601, 72.80457877828213], [21.10795732558601, 72.80457877828213]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_d5e53f3821227b8fcfe1fa9fea002e18 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/a07a635d9dc3decc99f0917272274094-8e056c6bf716448268b3aa0becd9a7d6/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoo
# No images found at location (16.918785, 96.183778) for NAIP
# No images found at location (16.918785, 96.183778) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8521bb2fd91bc1c06901d643b699033d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8521bb2fd91bc1c06901d643b699033d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8521bb2fd91bc1c06901d643b699033d = L.map(
#                 &quot;map_8521bb2fd91bc1c06901d643b699033d&quot;,
#                 {
#                     center: [16.918785, 96.183778],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41b652d7332aac7d188bba0d922a778c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8521bb2fd91bc1c06901d643b699033d);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8521bb2fd91bc1c06901d643b699033d);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_8521bb2fd91bc1c06901d643b699033d);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_8521bb2fd91bc1c06901d643b699033d
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_9a4418b689b4482d5af49db71d534204 = new L.Control.Draw(
#                 options
#             ).addTo( map_8521bb2fd91bc1c06901d643b699033d );
#             map_8521bb2fd91bc1c06901d643b699033d.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_8521bb2fd91bc1c06901d643b699033d.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_8521bb2fd91bc1c06901d643b699033d.setView(e.geocode.center, 11);
#             }).addTo(map_8521bb2fd91bc1c06901d643b699033d);
#
#
#
#             map_8521bb2fd91bc1c06901d643b699033d.fitBounds(
#                 [[16.918785, 96.183778], [16.918785, 96.183778]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_99d3867a11736a06230b384f28f0a49a = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/333e2a3e5e70c7b54264aab4d9cf1d6a-ee3f6d075b0c3798ef2b7b7caded826a/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opa
# No images found at location (29.424167, -95.190834) for NAIP
# No images found at location (29.424167, -95.190834) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9229c4c66f5665a9abb6e9911ef0cef6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9229c4c66f5665a9abb6e9911ef0cef6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9229c4c66f5665a9abb6e9911ef0cef6 = L.map(
#                 &quot;map_9229c4c66f5665a9abb6e9911ef0cef6&quot;,
#                 {
#                     center: [29.424167, -95.190834],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98cb574c17ca74517a470aec49d4b683 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9229c4c66f5665a9abb6e9911ef0cef6);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9229c4c66f5665a9abb6e9911ef0cef6);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_9229c4c66f5665a9abb6e9911ef0cef6);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_9229c4c66f5665a9abb6e9911ef0cef6
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_e85fcc885b4203e86ae099132217ee39 = new L.Control.Draw(
#                 options
#             ).addTo( map_9229c4c66f5665a9abb6e9911ef0cef6 );
#             map_9229c4c66f5665a9abb6e9911ef0cef6.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_9229c4c66f5665a9abb6e9911ef0cef6.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
# ...
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3dca313baa3429fce662a823d2b6b0e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3dca313baa3429fce662a823d2b6b0e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3dca313baa3429fce662a823d2b6b0e1 = L.map(
#                 &quot;map_3dca313baa3429fce662a823d2b6b0e1&quot;,
#                 {
#                     center: [26.76432142308992, 80.9085092703899],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c91c978fac71a1c078f669ee7ad3b50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3dca313baa3429fce662a823d2b6b0e1);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3dca313baa3429fce662a823d2b6b0e1);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_3dca313baa3429fce662a823d2b6b0e1);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_3dca313baa3429fce662a823d2b6b0e1
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_e6a89ba30e974f7d7780a93efb934250 = new L.Control.Draw(
#                 options
#             ).addTo( map_3dca313baa3429fce662a823d2b6b0e1 );
#             map_3dca313baa3429fce662a823d2b6b0e1.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_3dca313baa3429fce662a823d2b6b0e1.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_3dca313baa3429fce662a823d2b6b0e1.setView(e.geocode.center, 11);
#             }).addTo(map_3dca313baa3429fce662a823d2b6b0e1);
#
#
#
#             map_3dca313baa3429fce662a823d2b6b0e1.fitBounds(
#                 [[26.76432142308992, 80.9085092703899], [26.76432142308992, 80.9085092703899]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_6a092530247af325e3417c6b8e4c8446 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/baeeb6137abcefc9828f3bfa354f324e-0455899fc0fae239a6f3393e7634312b/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&q
# No images found at location (28.714936784527467, 77.08224540020566) for NAIP
# No images found at location (28.714936784527467, 77.08224540020566) for SkySat
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c5f724a36d1d324cd5af1bfadbe14a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c5f724a36d1d324cd5af1bfadbe14a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c5f724a36d1d324cd5af1bfadbe14a9 = L.map(
#                 &quot;map_6c5f724a36d1d324cd5af1bfadbe14a9&quot;,
#                 {
#                     center: [28.714936784527467, 77.08224540020566],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     locateControl: false,
#                     searchControl: true,
#                     layersControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d08e72bd4b56e725ac6210b68757d9e1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 30, &quot;maxZoom&quot;: 30, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c5f724a36d1d324cd5af1bfadbe14a9);
#
#
#             var tile_layer_d8a10569e63d9e6a292bbcbe8cbcde21 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6c5f724a36d1d324cd5af1bfadbe14a9);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_6c5f724a36d1d324cd5af1bfadbe14a9);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_6c5f724a36d1d324cd5af1bfadbe14a9
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_003147cd8ed255c71e77a13ada8576fd = new L.Control.Draw(
#                 options
#             ).addTo( map_6c5f724a36d1d324cd5af1bfadbe14a9 );
#             map_6c5f724a36d1d324cd5af1bfadbe14a9.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_6c5f724a36d1d324cd5af1bfadbe14a9.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_6c5f724a36d1d324cd5af1bfadbe14a9.setView(e.geocode.center, 11);
#             }).addTo(map_6c5f724a36d1d324cd5af1bfadbe14a9);
#
#
#
#             map_6c5f724a36d1d324cd5af1bfadbe14a9.fitBounds(
#                 [[28.714936784527467, 77.08224540020566], [28.714936784527467, 77.08224540020566]],
#                 {&quot;maxZoom&quot;: 13}
#             );
#
#
#             var tile_layer_bc1a6ff5d7982f9c258a5b0323eaa7f0 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/maps/76d8efde2dd62ea65ad7ab48f3b8c8c6-4d5bf9b40a9f472ab33ccb415f936a98/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;min

# %%
# Works sometimes, but unstable.
# for i, row in matches_df.iterrows():
#     get_image(row['lat_TRACE'], row['lon_TRACE'])
#     input("Press Enter to continue...")

# %%
# See export status
print(task.status())
# Out:
# {'state': 'UNSUBMITTED'}

# %%
# List active and completed export tasks
ee.data.listOperations()
# Out:
# [{'name': 'projects/earthengine-legacy/operations/KWA7YAL3M4SN5VPBXFFBUGNJ',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_28.714936784527467_77.08224540020566',
#    'createTime': '2023-05-16T12:44:03.245559Z',
#    'updateTime': '2023-05-16T12:45:36.663564Z',
#    'startTime': '2023-05-16T12:45:20.269672Z',
#    'endTime': '2023-05-16T12:45:36.663564Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 14.762529373168945},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/MCGAVC5SDLWXCIOCXUUJVE3Y',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_26.76432142308992_80.9085092703899',
#    'createTime': '2023-05-16T12:43:59.108643Z',
#    'updateTime': '2023-05-16T12:45:53.473191Z',
#    'startTime': '2023-05-16T12:45:02.433437Z',
#    'endTime': '2023-05-16T12:45:53.473191Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 24.929370880126953},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/ZNJUUF7F7VF6VCN3V5P6IKKU',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_17.495650677001862_78.58017126933838',
#    'createTime': '2023-05-16T12:43:55.168040Z',
#    'updateTime': '2023-05-16T12:45:20.989660Z',
#    'startTime': '2023-05-16T12:45:02.425179Z',
#    'endTime': '2023-05-16T12:45:20.989660Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 19.436311721801758},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/IUKNWTWB6STRLCEJIHYPG5AK',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_23.09561042983137_72.61721023760883',
#    'createTime': '2023-05-16T12:43:50.850694Z',
#    'updateTime': '2023-05-16T12:45:11.645018Z',
#    'startTime': '2023-05-16T12:45:02.420151Z',
#    'endTime': '2023-05-16T12:45:11.645018Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 5.537609100341797},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/35KGHHFYY2MYZLKEVFALSPHY',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_22.32654134700519_73.14954893568395',
#    'createTime': '2023-05-16T12:43:46.894910Z',
#    'updateTime': '2023-05-16T12:45:16.272075Z',
#    'startTime': '2023-05-16T12:45:02.402855Z',
#    'endTime': '2023-05-16T12:45:16.272075Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 12.2616548538208},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/D7OGIOQKHWSOTRWUBRUJSEL4',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2

#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_-34.5438228657023_-58.6069107055664',
#    'createTime': '2023-05-15T23:00:08.477889Z',
#    'updateTime': '2023-05-15T23:00:33.833393Z',
#    'startTime': '2023-05-15T23:00:18.303587Z',
#    'endTime': '2023-05-15T23:00:33.833393Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 9.182290077209473},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/6NOQ5PLYAL6JAO6BV3PRSHQ7',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Satellite_Image_Sentinal2_35.4716451185922_51.3355064392089',
#    'createTime': '2023-05-15T23:00:04.058656Z',
#    'updateTime': '2023-05-15T23:00:37.851053Z',
#    'startTime': '2023-05-15T23:00:18.290418Z',
#    'endTime': '2023-05-15T23:00:37.851053Z',
#    'type': 'EXPORT_IMAGE',
#    'destinationUris': ['https://drive.google.com/#folders/1IgGrTYBGtAX9Ue7OHkVA-zo-jJnTWpM-'],
#    'attempt': 1,
#    'progress': 1,
#    'stages': [{'displayName': 'Create Local Files',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Computation and writing of temporary files.'},
#     {'displayName': 'Write Files to Destination',
#      'completeWorkUnits': 1,
#      'totalWorkUnits': '1',
#      'description': 'Uploading of files to the export destination.'}],
#    'batchEecuUsageSeconds': 11.428955078125},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}},
#  {'name': 'projects/earthengine-legacy/operations/W25UINDDVZDUJJH65KWC3SQ6',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'FAILED',
#    'description': 'Ingest table: "projects/ee-hughrunyan/assets/m"',
#    'createTime': '2023-05-15T19:27:26.293664Z',
#    'updateTime': '2023-05-15T19:29:01.863870Z',
#    'startTime': '2023-05-15T19:28:23.322899Z',
#    'endTime': '2023-05-15T19:29:01.863870Z',
#    'type': 'INGEST_TABLE',
#    'attempt': 1},
#   'done': True,
#   'error': {'code': 3,
#    'message': "Cannot overwrite asset 'projects/ee-hughrunyan/assets/m'."}},
#  {'name': 'projects/earthengine-legacy/operations/EL22AIZ7RTVBSFJOR5GGAO43',
#   'metadata': {'@type': 'type.googleapis.com/google.earthengine.v1alpha.OperationMetadata',
#    'state': 'SUCCEEDED',
#    'description': 'Ingest table: "projects/ee-hughrunyan/assets/m"',
#    'createTime': '2023-05-15T19:26:56.912182Z',
#    'updateTime': '2023-05-15T19:28:25.579430Z',
#    'startTime': '2023-05-15T19:27:47.433112Z',
#    'endTime': '2023-05-15T19:28:25.579430Z',
#    'type': 'INGEST_TABLE',
#    'destinationUris': ['https://code.earthengine.google.com/?asset=projects/ee-hughrunyan/assets/m'],
#    'attempt': 1},
#   'done': True,
#   'response': {'@type': 'type.googleapis.com/google.protobuf.Empty'}}]

# %%
# Get a single image if desired
# Right now this makes a map with no error message but doesn't show an image. This image, for some
# reason, only has bands R, G, and NIR. For now, earlier code skips NAIP imagery if it has no B

dataset="USDA/NAIP/DOQQ"
bands = ['R', 'G']

#dataset="COPERNICUS/S2_SR_HARMONIZED"

# Sentinal-2 has a lot of bands to choose from, see GEE catalogue
#bands = ['TCI_R', 'TCI_G', 'TCI_B']

lat = matches_df.at[5, 'lat_TRACE']
lon = matches_df.at[5, 'lon_TRACE']
point = ee.Geometry.Point(lon, lat)
image_collection = ee.ImageCollection(dataset)\
        .filterBounds(point)\
        .sort('system:time_start', False)
    
region = point.buffer(2500).bounds()
composite = image_collection.median()
composite = composite.clip(region)
img = composite
#centroid = img.geometry().centroid(1).getInfo()['coordinates']
#Map = geemap.Map(center=[0, 0], zoom=12)
#Map.setCenter(lon=centroid[0], lat=centroid[1], zoom=12)
Map = geemap.Map(center=[lat, lon], zoom=13)
Map.addLayer(img, {'bands': bands, 'min': 0, 'max': 255}, (str(lat) + '_' + str(lon)))
Map.addLayer(point, {}, 'Point_' + str(lat) + '_' + str(lon))
display(Map)

# %%
# Used to just export without visualizing

sats_to_try = [load_NAIP, load_SkySat, load_Sentinal2]
sat_names = ['NAIP', 'SkySat', 'Sentinal2']

for i, row in matches_df.iterrows():
    lat = matches_df.at[i, 'lat_TRACE']
    lon = matches_df.at[i, 'lon_TRACE']
    point = ee.Geometry.Point(lon, lat)
    for i, sat in enumerate(sats_to_try):
        try:
            img, bands = sat(point, lat, lon)
            
            # Make sure there's actually an image for this satellite
            assert img.getInfo()['properties']['system:footprint']

            # Define export parameters
            exportParams = {
                'image': img,
                'description': 'Satellite_Image_' + sat_names[i] + '_' + str(lat) + '_' + str(lon),
                'region': img.geometry(),
                'folder': 'GEE_test', # specify Google Drive folder name 
                'fileFormat': 'GeoTIFF' # specify format
            }

            # Export the image to Google Drive
            task = ee.batch.Export.image.toDrive(**exportParams)
            task.start()
            print(sat_names[i] + ' exported.')
            break #Map, centroid
        except:
            print(f"No images found at location ({lat}, {lon}) for {sat_names[i]}")
            pass
# Out:
# No images found at location (35.4716451185922, 51.3355064392089) for NAIP
# No images found at location (35.4716451185922, 51.3355064392089) for SkySat
# No images found at location (-34.5438228657023, -58.6069107055664) for NAIP
# No images found at location (-34.5438228657023, -58.6069107055664) for SkySat
# No images found at location (18.68450504818949, 73.82404071330201) for NAIP
# No images found at location (18.68450504818949, 73.82404071330201) for SkySat
# No images found at location (21.10795732558601, 72.80457877828213) for NAIP
# No images found at location (21.10795732558601, 72.80457877828213) for SkySat
# No images found at location (16.918785, 96.183778) for NAIP
# No images found at location (16.918785, 96.183778) for SkySat
# No images found at location (29.424167, -95.190834) for SkySat
# No images found at location (22.2791687868323, 73.16836760547713) for NAIP
# No images found at location (22.2791687868323, 73.16836760547713) for SkySat
# No images found at location (19.23437053928207, 72.82799163482227) for NAIP
# No images found at location (19.23437053928207, 72.82799163482227) for SkySat
# No images found at location (18.89129204862876, 72.93548127368939) for NAIP
# No images found at location (18.89129204862876, 72.93548127368939) for SkySat
# No images found at location (41.21442292400268, 28.149789003382335) for NAIP
# No images found at location (41.21442292400268, 28.149789003382335) for SkySat
# No images found at location (23.249415733153228, 72.49924556974014) for NAIP
# No images found at location (23.249415733153228, 72.49924556974014) for SkySat
# No images found at location (22.32654134700519, 73.14954893568395) for NAIP
# No images found at location (22.32654134700519, 73.14954893568395) for SkySat
# No images found at location (23.09561042983137, 72.61721023760883) for NAIP
# No images found at location (23.09561042983137, 72.61721023760883) for SkySat
# No images found at location (17.495650677001862, 78.58017126933838) for NAIP
# No images found at location (17.495650677001862, 78.58017126933838) for SkySat
# No images found at location (26.76432142308992, 80.9085092703899) for NAIP
# No images found at location (26.76432142308992, 80.9085092703899) for SkySat
# No images found at location (28.714936784527467, 77.08224540020566) for NAIP
# No images found at location (28.714936784527467, 77.08224540020566) for SkySat
